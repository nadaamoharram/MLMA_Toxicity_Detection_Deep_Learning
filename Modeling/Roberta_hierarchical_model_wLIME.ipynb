# %% [markdown]
# # Multi-Task Hierarchical Modeling
# In multi-task hierarchical modeling, there is an explicit dependency structure between the tasks. The output of one task may be used as input (or conditioning context) for another.
#
# Example Hierarchies:
#
#   * Predict hatespeech first, then condition directness, target, etc., on that prediction.
#
#   * Predict target, then use it to inform group, because groups are nested under targets.

# %% [markdown]
#                  [Transformer]
#                       ↓
#                  [hate_head]
#                       ↓
#            [directness | hate]
#                       ↓
#         [target | directness, hate]
#                       ↓
#         [group | target, directness, hate]

# %% [markdown]
# Reasons we're exploring hierarchical modeling:
# - tasks are casually dependent
# - the data is imbalanced and need strong signals from simpler tasks

# %%
# !pip install -q evaluate torchinfo
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.7 MB/s eta 0:00:00

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaTokenizer, RobertaModel
import pandas as pd

import numpy as np
from datasets import Dataset
import evaluate
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import TrainingArguments, Trainer
from torchinfo import summary
import torch
from transformers import BertTokenizer, BertForSequenceClassification, BitsAndBytesConfig
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
import warnings

# %%
# Suppress warnings like encoder_attention_mask future warning
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#load dataset
train_df = pd.read_csv('/content/drive/MyDrive/DS266/Project/Data/combined_train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/DS266/Project/Data/combined_test.csv')
val_df = pd.read_csv('/content/drive/MyDrive/DS266/Project/Data/combined_val.csv')

# %%
train_df = train_df.dropna(subset=["text_cleaned"])
test_df = test_df.dropna(subset=["text_cleaned"])
val_df = val_df.dropna(subset=["text_cleaned"])

# %%
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

# %%
#convert to HuggingFace dataset / format
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)
val_dataset = Dataset.from_pandas(val_df)

# %%
sentiment_cols = [col for col in train_df.columns if col.startswith('sentiment_')]
sentiment_cols
# Out:
# ['sentiment_anger',
#  'sentiment_confusion',
#  'sentiment_disgust',
#  'sentiment_fear',
#  'sentiment_indifference',
#  'sentiment_normal',
#  'sentiment_sadness',
#  'sentiment_shock']

# %%
# Tokenizer
from transformers import AutoModel, AutoTokenizer

model_name = "xlm-roberta-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
base_model = AutoModel.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]

# %%
class HierarchicalDataset(torch.utils.data.Dataset):
    def __init__(self, df, tokenizer, max_len=128):
        self.df = df.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.sentiment_cols = [col for col in df.columns if col.startswith('sentiment_')]
        print(f"Detected sentiment columns: {self.sentiment_cols}")

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        encoding = self.tokenizer(row['text_cleaned'], padding='max_length', truncation=True, max_length=self.max_len, return_tensors='pt')

        hate = torch.tensor(row['hatespeech'], dtype=torch.float)
        directness = torch.tensor(row['directness_label'], dtype=torch.long)
        target = torch.tensor(row['target_label'], dtype=torch.long)
        group = torch.tensor(row['group_label'], dtype=torch.long)
        sentiments = torch.tensor(row[self.sentiment_cols].to_numpy(dtype='int64'), dtype=torch.float)


        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'hate': hate,
            'directness': directness,
            'target': target,
            'group': group,
            'sentiments': sentiments,
        }

# %% [markdown]
# # Hierarchical Multi-Task Model

# %%
import torch.nn as nn

class HierarchicalMultiTaskModel(nn.Module):
    def __init__(self, base_model, hidden_dim=768, num_groups=17, num_targets=4, num_directness=3, sentiment_size=8):
        super().__init__()
        self.encoder = base_model

        self.hate_head = nn.Linear(hidden_dim, 1)
        self.directness_head = nn.Linear(hidden_dim + 1, 3)
        self.target_head = nn.Linear(hidden_dim + 3, 7)
        self.group_head = nn.Linear(hidden_dim + 7, 17)
        self.sentiment_head = nn.Linear(hidden_dim, 8)

    def forward(self, input_ids, attention_mask):
        outputs = self.encoder(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.last_hidden_state[:, 0, :]  # CLS token

        hate_logits = self.hate_head(pooled_output)
        directness_logits = self.directness_head(torch.cat([pooled_output, torch.sigmoid(hate_logits)], dim=1))
        target_logits = self.target_head(torch.cat([pooled_output, torch.softmax(directness_logits, dim=1)], dim=1))
        group_logits = self.group_head(torch.cat([pooled_output, torch.softmax(target_logits, dim=1)], dim=1))
        sentiment_logits = self.sentiment_head(pooled_output)

        return {
            'hate': hate_logits.squeeze(-1),
            'directness': directness_logits,
            'target': target_logits,
            'group': group_logits,
            'sentiments': sentiment_logits
        }

# %% [markdown]
# # Loss Function

# %%
train_dataset = HierarchicalDataset(train_df, tokenizer, max_len=128) #, sentiment_cols=sentiment_cols)
val_dataset =HierarchicalDataset(val_df, tokenizer, max_len=128)#, sentiment_cols=sentiment_cols)
test_dataset = HierarchicalDataset(test_df, tokenizer, max_len=128) #, sentiment_cols=sentiment_cols)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)
# Out:
# Detected sentiment columns: ['sentiment_anger', 'sentiment_confusion', 'sentiment_disgust', 'sentiment_fear', 'sentiment_indifference', 'sentiment_normal', 'sentiment_sadness', 'sentiment_shock']
# Detected sentiment columns: ['sentiment_anger', 'sentiment_confusion', 'sentiment_disgust', 'sentiment_fear', 'sentiment_indifference', 'sentiment_normal', 'sentiment_sadness', 'sentiment_shock']
# Detected sentiment columns: ['sentiment_anger', 'sentiment_confusion', 'sentiment_disgust', 'sentiment_fear', 'sentiment_indifference', 'sentiment_normal', 'sentiment_sadness', 'sentiment_shock']

# %%
from torch.optim import AdamW
from tqdm import tqdm
# Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = HierarchicalMultiTaskModel(base_model).to(device)

# Optimizer
optimizer = AdamW(model.parameters(), lr=2e-5)

# %%
def compute_loss(outputs, labels):
    loss_fn_bce = nn.BCEWithLogitsLoss()
    loss_fn_ce = nn.CrossEntropyLoss()

    hate_loss = loss_fn_bce(outputs['hate'], labels['hate'])
    directness_loss = loss_fn_ce(outputs['directness'], labels['directness'])
    target_loss = loss_fn_ce(outputs['target'], labels['target'])
    group_loss = loss_fn_ce(outputs['group'], labels['group'])
    sentiments_loss = loss_fn_bce(outputs['sentiments'], labels['sentiments'])

    total_loss = hate_loss + directness_loss + target_loss + group_loss + sentiments_loss
    return total_loss

# %% [markdown]
# # Evaluate Function

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np

def evaluate1(model, dataloader):
    model.eval()
    hate_preds, hate_labels = [], []
    dir_preds, dir_labels = [], []
    tgt_preds, tgt_labels = [], []
    grp_preds, grp_labels = [], []
    sent_preds, sent_labels = [], []

    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)

            # Binary hate
            preds = (torch.sigmoid(outputs['hate']) > 0.5).int().cpu()
            labels = batch['hate'].int()
            hate_preds.extend(preds.numpy())
            hate_labels.extend(labels.numpy())

            # Multi-class
            for task in ['directness', 'target', 'group']:
                preds = torch.argmax(outputs[task], dim=1).cpu()
                labels = batch[task]
                if task == 'directness':
                    dir_preds.extend(preds.numpy())
                    dir_labels.extend(labels.numpy())
                elif task == 'target':
                    tgt_preds.extend(preds.numpy())
                    tgt_labels.extend(labels.numpy())
                else:
                    grp_preds.extend(preds.numpy())
                    grp_labels.extend(labels.numpy())

            # Sentiment: multilabel
            sent_out = (torch.sigmoid(outputs['sentiments']) > 0.5).int().cpu()
            sent_lbl = batch['sentiments'].int()
            sent_preds.append(sent_out.numpy())
            sent_labels.append(sent_lbl.numpy())

    # Stack sentiment arrays
    sent_preds = np.vstack(sent_preds)
    sent_labels = np.vstack(sent_labels)

    print("\nHATE (Binary):")
    print("  Accuracy:", accuracy_score(hate_labels, hate_preds))
    print("  Precision (micro):", precision_score(hate_labels, hate_preds, average='micro'))
    print("  Recall (micro):", recall_score(hate_labels, hate_preds, average='micro'))
    print("  F1 Score (micro):", f1_score(hate_labels, hate_preds, average='micro'))

    print("\nDIRECTNESS (Multi-Class):")
    print("  Accuracy:", accuracy_score(dir_labels, dir_preds))
    print("  Precision (micro):", precision_score(dir_labels, dir_preds, average='micro'))
    print("  Recall (micro):", recall_score(dir_labels, dir_preds, average='micro'))
    print("  F1 Score (micro):", f1_score(dir_labels, dir_preds, average='micro'))

    print("\nTARGET (Multi-Class):")
    print("  Accuracy:", accuracy_score(tgt_labels, tgt_preds))
    print("  Precision (micro):", precision_score(tgt_labels, tgt_preds, average='micro'))
    print("  Recall (micro):", recall_score(tgt_labels, tgt_preds, average='micro'))
    print("  F1 Score (micro):", f1_score(tgt_labels, tgt_preds, average='micro'))

    print("\nGROUP (Multi-Class):")
    print("  Accuracy:", accuracy_score(grp_labels, grp_preds))
    print("  Precision (micro):", precision_score(grp_labels, grp_preds, average='micro'))
    print("  Recall (micro):", recall_score(grp_labels, grp_preds, average='micro'))
    print("  F1 Score (micro):", f1_score(grp_labels, grp_preds, average='micro'))

    print("\nSENTIMENTS (Multi-Label, 8 classes):")
    print("  Precision (micro):", precision_score(sent_labels, sent_preds, average='micro'))
    print("  Recall (micro):", recall_score(sent_labels, sent_preds, average='micro'))
    print("  F1 Score (micro):", f1_score(sent_labels, sent_preds, average='micro'))

           # Convert all tasks to flat binary comparisons
    flat_preds = np.concatenate([
        np.array(hate_preds).reshape(-1),
        np.array(dir_preds).reshape(-1),
        np.array(tgt_preds).reshape(-1),
        np.array(grp_preds).reshape(-1),
        sent_preds.flatten()
    ])

    flat_labels = np.concatenate([
        np.array(hate_labels).reshape(-1),
        np.array(dir_labels).reshape(-1),
        np.array(tgt_labels).reshape(-1),
        np.array(grp_labels).reshape(-1),
        sent_labels.flatten()
    ])

    print("\nOVERALL (All Tasks Combined - Micro Average):")
    print("  Precision (micro):", precision_score(flat_labels, flat_preds, average='micro', zero_division=0))
    print("  Recall (micro):", recall_score(flat_labels, flat_preds, average='micro', zero_division=0))
    print("  F1 Score (micro):", f1_score(flat_labels, flat_preds, average='micro', zero_division=0))

# %% [markdown]
# # Model Training

# %%
def train(model, train_loader, val_loader, epochs=3):
    model.train()

    for epoch in range(epochs):
        total_loss = 0
        loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}")

        for batch in loop:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            labels = {
                'hate': batch['hate'].to(device),
                'directness': batch['directness'].to(device),
                'target': batch['target'].to(device),
                'group': batch['group'].to(device),
                'sentiments': batch['sentiments'].to(device)
            }

            optimizer.zero_grad()
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = compute_loss(outputs, labels)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            total_loss += loss.item()
            loop.set_postfix(loss=loss.item())

        avg_train_loss = total_loss / len(train_loader)
        print(f"\nEpoch {epoch+1} Training Loss: {avg_train_loss:.4f}")

        #evaluate1(model, val_loader)

# %%
train(model, train_loader, val_loader, epochs=3)
# Out:
# Epoch 1/3: 100%|██████████| 960/960 [11:19<00:00,  1.41it/s, loss=3.38]
# Epoch 1 Training Loss: 2.9698
# Epoch 2/3: 100%|██████████| 960/960 [11:16<00:00,  1.42it/s, loss=1.87]
# Epoch 2 Training Loss: 2.1334
# Epoch 3/3: 100%|██████████| 960/960 [11:15<00:00,  1.42it/s, loss=2.48]
# Epoch 3 Training Loss: 1.9879

# %%
# train(model, train_loader, val_loader, epochs=3)

# %%
evaluate1(model, val_loader)
# Out:
# Evaluating: 100%|██████████| 122/122 [00:24<00:00,  4.89it/s]
# HATE (Binary):
#   Accuracy: 0.9507692307692308
#   Precision (micro): 0.9507692307692308
#   Recall (micro): 0.9507692307692308
#   F1 Score (micro): 0.9507692307692308
#
# DIRECTNESS (Multi-Class):
#   Accuracy: 0.8415384615384616
#   Precision (micro): 0.8415384615384616
#   Recall (micro): 0.8415384615384616
#   F1 Score (micro): 0.8415384615384616
#
# TARGET (Multi-Class):
#   Accuracy: 0.7974358974358975
#   Precision (micro): 0.7974358974358975
#   Recall (micro): 0.7974358974358975
#   F1 Score (micro): 0.7974358974358975
#
# GROUP (Multi-Class):
#   Accuracy: 0.7428205128205129
#   Precision (micro): 0.7428205128205129
#   Recall (micro): 0.7428205128205129
#   F1 Score (micro): 0.7428205128205129
#
# SENTIMENTS (Multi-Label, 8 classes):
#   Precision (micro): 0.6847417037290455
#   Recall (micro): 0.6071591081450023
#   F1 Score (micro): 0.6436208698448428
#
# OVERALL (All Tasks Combined - Micro Average):
#   Precision (micro): 0.8496581196581197
#   Recall (micro): 0.8496581196581197
#   F1 Score (micro): 0.8496581196581197

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
import numpy as np
import warnings

# Suppress warnings like encoder_attention_mask future warning
warnings.filterwarnings("ignore", category=FutureWarning)

def generate_confusion_matrices_by_language(model, df, tokenizer, device, batch_size=8):
    model.eval()
    model.to(device)

    label_names = {
        'hate': ['Not Hate', 'Hate'],
        'directness': ['direct', 'indirect', 'normal'],
        'target': ["disability", "gender", "normal", "origin", "other", "religion", "sexual_orientation"],
        'group': ["african_descent", "arabs", "asians", "christian", "gay", "hispanics", "immigrants",
                  "indian/hindu", "individual", "jews", "left_wing_people", "muslims", "normal", "other",
                  "refugees", "special_needs", "women"],
        'sentiments': ['sentiment_anger','sentiment_confusion','sentiment_disgust','sentiment_fear',
                       'sentiment_indifference','sentiment_normal','sentiment_sadness','sentiment_shock']
    }

    language_map = {
        enc: lang for enc, lang in df[['language_encoded', 'language']].drop_duplicates().values
    }

    languages = df['language_encoded'].unique()

    for lang_code in languages:
        lang_name = language_map.get(lang_code, f"lang_{lang_code}")
        print(f"\n Language: {lang_name} (encoded: {lang_code})")

        lang_df = df[df['language_encoded'] == lang_code]
        if len(lang_df) == 0:
            print(f" No data for language {lang_name}. Skipping...")
            continue

        dataset = HierarchicalDataset(lang_df, tokenizer)
        loader = DataLoader(dataset, batch_size=batch_size)

        all_true = {k: [] for k in ['hate', 'directness', 'target', 'group', 'sentiments']}
        all_preds = {k: [] for k in ['hate', 'directness', 'target', 'group', 'sentiments']}

        for batch in loader:
            batch = {k: v.to(device) for k, v in batch.items()}
            with torch.no_grad():
                outputs = model(input_ids=batch['input_ids'], attention_mask=batch['attention_mask'])

            # HATE (binary)
            if 'hate' in outputs:
                true_hate = batch['hate'].detach().cpu().numpy()
                pred_hate = (torch.sigmoid(outputs['hate']).detach().cpu().numpy() > 0.5).astype(int)
                all_true['hate'].extend(true_hate)
                all_preds['hate'].extend(pred_hate)

            # DIRECTNESS, TARGET, GROUP (multiclass)
            for task in ['directness', 'target', 'group']:
                if task in outputs:
                    true_task = batch[task].detach().cpu().numpy()
                    pred_task = torch.argmax(outputs[task], dim=1).detach().cpu().numpy()
                    all_true[task].extend(true_task)
                    all_preds[task].extend(pred_task)

            # SENTIMENTS (multilabel)
            if 'sentiments' in outputs:
                true_sent = batch['sentiments'].detach().cpu().numpy()
                pred_sent = (torch.sigmoid(outputs['sentiments']).detach().cpu().numpy() > 0.5).astype(int)
                all_true['sentiments'].append(true_sent)
                all_preds['sentiments'].append(pred_sent)

        # Plot confusion matrices for single-label tasks
        for task in ['hate', 'directness', 'target', 'group']:
            if len(all_true[task]) == 0 or len(all_preds[task]) == 0:
                print(f" Skipping {task} for language {lang_name} due to no data.")
                continue
            labels = label_names[task]
            used_indices = sorted(set(all_true[task]) | set(all_preds[task]))
            used_labels = [labels[int(i)] for i in used_indices]
            cm = confusion_matrix(all_true[task], all_preds[task], labels=used_indices)
            disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=used_labels)
            disp.plot(cmap='Blues')
            plt.title(f'{task.capitalize()} | Language: {lang_name}')
            # Rotate ticks based on task
            # if task == 'group':
            #     plt.xticks(rotation=90, fontsize=8)
            #     plt.yticks(rotation=0, fontsize=8)
            # else:
            #     plt.xticks(rotation=45)
            #     plt.yticks(rotation=45)
            plt.xticks(rotation=90)
            plt.yticks(rotation=0)
            plt.tight_layout()
            plt.show()


        # Plot confusion matrices for multilabel sentiments
        if len(all_true['sentiments']) > 0 and len(all_preds['sentiments']) > 0:
            true_sent_arr = np.vstack(all_true['sentiments'])
            pred_sent_arr = np.vstack(all_preds['sentiments'])

            for i, name in enumerate(label_names['sentiments']):
                cm = confusion_matrix(true_sent_arr[:, i], pred_sent_arr[:, i])
                disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[f'Not {name}', name])
                disp.plot(cmap='Purples')
                plt.title(f'Sentiment: {name.replace("sentiment_", "").capitalize()} | Language: {lang_name}')
                plt.xticks(rotation=90)
                #plt.yticks(rotation=90)
                plt.tight_layout()
                plt.show()
        else:
            print(f"Skipping sentiments for language {lang_name} due to no data.")

# %%
generate_confusion_matrices_by_language(model, val_df, tokenizer, device)
# Out:
#  Language: french (encoded: 1)
# Detected sentiment columns: ['sentiment_anger', 'sentiment_confusion', 'sentiment_disgust', 'sentiment_fear', 'sentiment_indifference', 'sentiment_normal', 'sentiment_sadness', 'sentiment_shock']
#  Language: arabic (encoded: 2)
# Detected sentiment columns: ['sentiment_anger', 'sentiment_confusion', 'sentiment_disgust', 'sentiment_fear', 'sentiment_indifference', 'sentiment_normal', 'sentiment_sadness', 'sentiment_shock
/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  81%|████████  | 99/122 [00:20<00:04,  4.70it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  82%|████████▏ | 100/122 [00:20<00:04,  4.67it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  83%|████████▎ | 101/122 [00:20<00:04,  4.68it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  84%|████████▎ | 102/122 [00:20<00:04,  4.67it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  84%|████████▍ | 103/122 [00:21<00:04,  4.65it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  85%|████████▌ | 104/122 [00:21<00:03,  4.60it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  86%|████████▌ | 105/122 [00:21<00:03,  4.63it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  87%|████████▋ | 106/122 [00:21<00:03,  4.65it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  88%|████████▊ | 107/122 [00:22<00:03,  4.62it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  89%|████████▊ | 108/122 [00:22<00:03,  4.57it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  89%|████████▉ | 109/122 [00:22<00:02,  4.58it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  90%|█████████ | 110/122 [00:22<00:02,  4.67it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  91%|█████████ | 111/122 [00:22<00:02,  4.75it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  92%|█████████▏| 112/122 [00:23<00:02,  4.77it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  93%|█████████▎| 113/122 [00:23<00:01,  4.77it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  93%|█████████▎| 114/122 [00:23<00:01,  4.82it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  94%|█████████▍| 115/122 [00:23<00:01,  4.84it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  95%|█████████▌| 116/122 [00:23<00:01,  4.87it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  96%|█████████▌| 117/122 [00:24<00:01,  4.87it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  97%|█████████▋| 118/122 [00:24<00:00,  4.87it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  98%|█████████▊| 119/122 [00:24<00:00,  4.86it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  98%|█████████▊| 120/122 [00:24<00:00,  4.88it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  99%|█████████▉| 121/122 [00:24<00:00,  4.89it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating: 100%|██████████| 122/122 [00:25<00:00,  4.86it/s]
# HATE (Binary):
#   Accuracy: 0.9505128205128205
#   Precision (micro): 0.9505128205128205
#   Recall (micro): 0.9505128205128205
#   F1 Score (micro): 0.9505128205128205
#
# DIRECTNESS (Multi-Class):
#   Accuracy: 0.8428205128205128
#   Precision (micro): 0.8428205128205128
#   Recall (micro): 0.8428205128205128
#   F1 Score (micro): 0.8428205128205128
#
# TARGET (Multi-Class):
#   Accuracy: 0.8043589743589744
#   Precision (micro): 0.8043589743589744
#   Recall (micro): 0.8043589743589744
#   F1 Score (micro): 0.8043589743589744
#
# GROUP (Multi-Class):
#   Accuracy: 0.7441025641025641
#   Precision (micro): 0.7441025641025641
#   Recall (micro): 0.7441025641025641
#   F1 Score (micro): 0.7441025641025641
#
# SENTIMENTS (Multi-Label, 8 classes):
#   Precision (micro): 0.7266624711558632
#   Recall (micro): 0.5254057333535568
#   F1 Score (micro): 0.6098591549295774
#
# OVERALL (All Tasks Combined - Micro Average):
#   Precision (micro): 0.8504487179487179
#   Recall (micro): 0.8504487179487179
#   F1 Score (micro): 0.8504487179487179

# %% [markdown]
# # Confusion Matrix

# %%
generate_confusion_matrices_by_language(model, val_df, tokenizer, device)
# Out:
# 📘 Language: french (encoded: 1)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# ⚠️ Sentiment shape mismatch for language french. Got (959, 0) vs (959, 8). Skipping sentiment confusion matrices.
#
# 📘 Language: arabic (encoded: 2)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# ⚠️ Sentiment shape mismatch for language arabic. Got (786, 0) vs (786, 8). Skipping sentiment confusion matrices.
#
# 📘 Language: english (encoded: 0)
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# ⚠️ Sentiment shape mismatch for language english. Got (2155, 0) vs (2155, 8). Skipping sentiment confusion matrices.

# %% [markdown]
# batch size 64

# %%
train(model, train_loader, val_loader, epochs=3)
# Out:
# Epoch 1/3:   0%|          | 0/480 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   0%|          | 1/480 [00:01<10:24,  1.30s/it, loss=5.94]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   0%|          | 2/480 [00:02<10:06,  1.27s/it, loss=5.09]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   1%|          | 3/480 [00:03<09:58,  1.26s/it, loss=5.39]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   1%|          | 4/480 [00:05<09:55,  1.25s/it, loss=5.4]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   1%|          | 5/480 [00:06<09:55,  1.25s/it, loss=5.19]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   1%|▏         | 6/480 [00:07<09:56,  1.26s/it, loss=4.97]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   1%|▏         | 7/480 [00:08<09:58,  1.26s/it, loss=4.64]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   2%|▏         | 8/480 [00:10<09:55,  1.26s/it, loss=5.63]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   2%|▏         | 9/480 [00:11<09:53,  1.26s/it, loss=4.71]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   2%|▏         | 10/480 [00:12<09:53,  1.26s/it, loss=5.07]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   2%|▏         | 11/480 [00:13<09:52,  1.26s/it, loss=4.67]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   2%|▎         | 12/480 [00:15<09:50,  1.26s/it, loss=4.47]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   3%|▎         | 13/480 [00:16<09:48,  1.26s/it, loss=4.73]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   3%|▎         | 14/480 [00:17<09:45,  1.26s/it, loss=4.64]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   3%|▎         | 15/480 [00:18<09:45,  1.26s/it, loss=4.72]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   3%|▎         | 16/480 [00:20<09:49,  1.27s/it, loss=4.66]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   4%|▎         | 17/480 [00:21<09:48,  1.27s/it, loss=5.07]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   4%|▍         | 18/480 [00:22<09:46,  1.27s/it, loss=4.26]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   4%|▍         | 19/480 [00:24<09:44,  1.27s/it, loss=5.33]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   4%|▍         | 20/480 [00:25<09:43,  1.27s/it, loss=4.18]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   4%|▍         | 21/480 [00:26<09:41,  1.27s/it, loss=4.75]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   5%|▍         | 22/480 [00:27<09:41,  1.27s/it, loss=4.46]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   5%|▍         | 23/480 [00:29<09:41,  1.27s/it, loss=4.67]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   5%|▌         | 24/480 [00:30<09:40,  1.27s/it, loss=5.04]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   5%|▌         | 25/480 [00:31<09:40,  1.28s/it, loss=4.29]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   5%|▌         | 26/480 [00:32<09:42,  1.28s/it, loss=4.44]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   6%|▌         | 27/480 [00:34<09:44,  1.29s/it, loss=4.38]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   6%|▌         | 28/480 [00:35<09:47,  1.30s/it, loss=3.76]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   6%|▌         | 29/480 [00:36<09:42,  1.29s/it, loss=4.66]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   6%|▋         | 30/480 [00:38<09:40,  1.29s/it, loss=5.1]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   6%|▋         | 31/480 [00:39<09:40,  1.29s/it, loss=4.93]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   7%|▋         | 32/480 [00:40<09:42,  1.30s/it, loss=4.11]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   7%|▋         | 33/480 [00:42<09:39,  1.30s/it, loss=4.79]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   7%|▋         | 34/480 [00:43<09:38,  1.30s/it, loss=4.75]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   7%|▋         | 35/480 [00:44<09:36,  1.30s/it, loss=4.53]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   8%|▊         | 36/480 [00:45<09:39,  1.30s/it, loss=4.28]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   8%|▊         | 37/480 [00:47<09:39,  1.31s/it, loss=3.91]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   8%|▊         | 38/480 [00:48<09:39,  1.31s/it, loss=4.27]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   8%|▊         | 39/480 [00:49<09:36,  1.31s/it, loss=4.22]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   8%|▊         | 40/480 [00:51<09:33,  1.30s/it, loss=4.56]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   9%|▊         | 41/480 [00:52<09:31,  1.30s/it, loss=4.31]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   9%|▉         | 42/480 [00:53<09:29,  1.30s/it, loss=4.32]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   9%|▉         | 43/480 [00:55<09:28,  1.30s/it, loss=3.29]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   9%|▉         | 44/480 [00:56<09:29,  1.31s/it, loss=3.91]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:   9%|▉         | 45/480 [00:57<09:28,  1.31s/it, loss=4.08]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  10%|▉         | 46/480 [00:59<09:33,  1.32s/it, loss=3.72]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  10%|▉         | 47/480 [01:00<09:33,  1.32s/it, loss=3.98]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  10%|█         | 48/480 [01:01<09:34,  1.33s/it, loss=5.21]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  10%|█         | 49/480 [01:03<09:31,  1.33s/it, loss=4.52]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  10%|█         | 50/480 [01:04<09:29,  1.32s/it, loss=4.25]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  11%|█         | 51/480 [01:05<09:28,  1.32s/it, loss=4.11]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  11%|█         | 52/480 [01:07<09:25,  1.32s/it, loss=3.91]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  11%|█         | 53/480 [01:08<09:24,  1.32s/it, loss=4.09]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  11%|█▏        | 54/480 [01:09<09:23,  1.32s/it, loss=4.21]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  11%|█▏        | 55/480 [01:10<09:22,  1.32s/it, loss=4.53]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  12%|█▏        | 56/480 [01:12<09:25,  1.33s/it, loss=4.3]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  12%|█▏        | 57/480 [01:13<09:26,  1.34s/it, loss=3.69]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  12%|█▏        | 58/480 [01:15<09:25,  1.34s/it, loss=4.03]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  12%|█▏        | 59/480 [01:16<09:28,  1.35s/it, loss=3.88]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  12%|█▎        | 60/480 [01:17<09:24,  1.35s/it, loss=5.06]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  13%|█▎        | 61/480 [01:19<09:23,  1.34s/it, loss=3.74]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  13%|█▎        | 62/480 [01:20<09:21,  1.34s/it, loss=4.07]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  13%|█▎        | 63/480 [01:21<09:20,  1.34s/it, loss=3.52]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  13%|█▎        | 64/480 [01:23<09:19,  1.34s/it, loss=3.63]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  14%|█▎        | 65/480 [01:24<09:17,  1.34s/it, loss=4.14]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  14%|█▍        | 66/480 [01:25<09:18,  1.35s/it, loss=3.73]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  14%|█▍        | 67/480 [01:27<09:19,  1.36s/it, loss=3.74]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  14%|█▍        | 68/480 [01:28<09:17,  1.35s/it, loss=3.95]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  14%|█▍        | 69/480 [01:29<09:15,  1.35s/it, loss=5.04]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  15%|█▍        | 70/480 [01:31<09:13,  1.35s/it, loss=3.85]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  15%|█▍        | 71/480 [01:32<09:11,  1.35s/it, loss=3.14]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  15%|█▌        | 72/480 [01:33<09:08,  1.34s/it, loss=3.97]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  15%|█▌        | 73/480 [01:35<09:06,  1.34s/it, loss=4.14]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  15%|█▌        | 74/480 [01:36<09:04,  1.34s/it, loss=4.01]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  16%|█▌        | 75/480 [01:37<09:02,  1.34s/it, loss=3.15]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  16%|█▌        | 76/480 [01:39<09:05,  1.35s/it, loss=3.87]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  16%|█▌        | 77/480 [01:40<09:05,  1.35s/it, loss=4.38]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  16%|█▋        | 78/480 [01:42<09:03,  1.35s/it, loss=3.67]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  16%|█▋        | 79/480 [01:43<08:59,  1.34s/it, loss=4.27]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  17%|█▋        | 80/480 [01:44<08:56,  1.34s/it, loss=4]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  17%|█▋        | 81/480 [01:46<08:54,  1.34s/it, loss=3.78]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  17%|█▋        | 82/480 [01:47<08:53,  1.34s/it, loss=3.65]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  17%|█▋        | 83/480 [01:48<08:51,  1.34s/it, loss=3.6]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  18%|█▊        | 84/480 [01:50<08:49,  1.34s/it, loss=3.31]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  18%|█▊        | 85/480 [01:51<08:51,  1.35s/it, loss=3.86]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  18%|█▊        | 86/480 [01:52<08:49,  1.34s/it, loss=3.99]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  18%|█▊        | 87/480 [01:54<08:51,  1.35s/it, loss=3.42]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  18%|█▊        | 88/480 [01:55<08:45,  1.34s/it, loss=4.61]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:  19%|█▊        | 89/480 [01:56<08:42,  1.34s/it, loss=3.44]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1/3:
/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  61%|██████    | 37/61 [00:16<00:10,  2.20it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  62%|██████▏   | 38/61 [00:16<00:10,  2.23it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  64%|██████▍   | 39/61 [00:17<00:09,  2.26it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  66%|██████▌   | 40/61 [00:17<00:09,  2.27it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  67%|██████▋   | 41/61 [00:18<00:08,  2.29it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  69%|██████▉   | 42/61 [00:18<00:08,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  70%|███████   | 43/61 [00:18<00:07,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  72%|███████▏  | 44/61 [00:19<00:07,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  74%|███████▍  | 45/61 [00:19<00:06,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  75%|███████▌  | 46/61 [00:20<00:06,  2.31it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  77%|███████▋  | 47/61 [00:20<00:06,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  79%|███████▊  | 48/61 [00:21<00:05,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  80%|████████  | 49/61 [00:21<00:05,  2.31it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  82%|████████▏ | 50/61 [00:21<00:04,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  84%|████████▎ | 51/61 [00:22<00:04,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  85%|████████▌ | 52/61 [00:22<00:03,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  87%|████████▋ | 53/61 [00:23<00:03,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  89%|████████▊ | 54/61 [00:23<00:03,  2.31it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  90%|█████████ | 55/61 [00:24<00:02,  2.31it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  92%|█████████▏| 56/61 [00:24<00:02,  2.31it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  93%|█████████▎| 57/61 [00:25<00:01,  2.32it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  95%|█████████▌| 58/61 [00:25<00:01,  2.32it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  97%|█████████▋| 59/61 [00:25<00:00,  2.29it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating:  98%|█████████▊| 60/61 [00:26<00:00,  2.30it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Evaluating: 100%|██████████| 61/61 [00:26<00:00,  2.28it/s]
# HATE (Binary):
#   Accuracy: 0.9482051282051283
#   Precision (micro): 0.9482051282051283
#   Recall (micro): 0.9482051282051283
#   F1 Score (micro): 0.9482051282051283
#
# DIRECTNESS (Multi-Class):
#   Accuracy: 0.8441025641025641
#   Precision (micro): 0.8441025641025641
#   Recall (micro): 0.8441025641025641
#   F1 Score (micro): 0.8441025641025641
#
# TARGET (Multi-Class):
#   Accuracy: 0.7982051282051282
#   Precision (micro): 0.7982051282051282
#   Recall (micro): 0.7982051282051282
#   F1 Score (micro): 0.7982051282051282
#
# GROUP (Multi-Class):
#   Accuracy: 0.7366666666666667
#   Precision (micro): 0.7366666666666667
#   Recall (micro): 0.7366666666666667
#   F1 Score (micro): 0.7366666666666667
#
# SENTIMENTS (Multi-Label, 8 classes):
#   Precision (micro): 0.726764645001035
#   Recall (micro): 0.5325345062945548
#   F1 Score (micro): 0.614670868347339

# %%
train(model, train_loader, val_loader, epochs=3)
# Out:
# Epoch 1/3: 100%|██████████| 480/480 [10:55<00:00,  1.37s/it, loss=1.68]
# Epoch 1 Training Loss: 2.1268
# Evaluating: 100%|██████████| 61/61 [00:26<00:00,  2.26it/s]
# HATE (Binary):
#   Accuracy: 0.9525641025641025
#   Precision (micro): 0.9525641025641025
#   Recall (micro): 0.9525641025641025
#   F1 Score (micro): 0.9525641025641025
#
# DIRECTNESS (Multi-Class):
#   Accuracy: 0.84
#   Precision (micro): 0.84
#   Recall (micro): 0.84
#   F1 Score (micro): 0.84
#
# TARGET (Multi-Class):
#   Accuracy: 0.7941025641025641
#   Precision (micro): 0.7941025641025641
#   Recall (micro): 0.7941025641025641
#   F1 Score (micro): 0.7941025641025641
#
# GROUP (Multi-Class):
#   Accuracy: 0.7266666666666667
#   Precision (micro): 0.7266666666666667
#   Recall (micro): 0.7266666666666667
#   F1 Score (micro): 0.7266666666666667
#
# SENTIMENTS (Multi-Label, 8 classes):
#   Precision (micro): 0.6912293314162473
#   Recall (micro): 0.5833459730016685
#   F1 Score (micro): 0.6327218886238382
# Epoch 2/3: 100%|██████████| 480/480 [10:23<00:00,  1.30s/it, loss=2.05]
# Epoch 2 Training Loss: 1.9325
# Evaluating: 100%|██████████| 61/61 [00:26<00:00,  2.27it/s]
# HATE (Binary):
#   Accuracy: 0.9482051282051283
#   Precision (micro): 0.9482051282051283
#   Recall (micro): 0.9482051282051283
#   F1 Score (micro): 0.9482051282051283
#
# DIRECTNESS (Multi-Class):
#   Accuracy: 0.8397435897435898
#   Precision (micro): 0.8397435897435898
#   Recall (micro): 0.8397435897435898
#   F1 Score (micro): 0.8397435897435898
#
# TARGET (Multi-Class):
#   Accuracy: 0.7976923076923077
#   Precision (micro): 0.7976923076923077
#   Recall (micro): 0.7976923076923077
#   F1 Score (micro): 0.7976923076923077
#
# GROUP (Multi-Class):
#   Accuracy: 0.7397435897435898
#   Precision (micro): 0.7397435897435898
#   Recall (micro): 0.7397435897435898
#   F1 Score (micro): 0.7397435897435898
#
# SENTIMENTS (Multi-Label, 8 classes):
#   Precision (micro): 0.7299207539087599
#   Recall (micro): 0.5169118762323677
#   F1 Score (micro): 0.6052210974960043
# Epoch 3/3: 100%|██████████| 480/480 [10:23<00:00,  1.30s/it, loss=1.6]
# Epoch 3 Training Loss: 1.7657
# Evaluating: 100%|██████████| 61/61 [00:26<00:00,  2.27it/s]
# HATE (Binary):
#   Accuracy: 0.9502564102564103
#   Precision (micro): 0.9502564102564103
#   Recall (micro): 0.9502564102564103
#   F1 Score (micro): 0.9502564102564103
#
# DIRECTNESS (Multi-Class):
#   Accuracy: 0.8438461538461538
#   Precision (micro): 0.8438461538461538
#   Recall (micro): 0.8438461538461538
#   F1 Score (micro): 0.8438461538461538
#
# TARGET (Multi-Class):
#   Accuracy: 0.8058974358974359
#   Precision (micro): 0.8058974358974359
#   Recall (micro): 0.8058974358974359
#   F1 Score (micro): 0.8058974358974359
#
# GROUP (Multi-Class):
#   Accuracy: 0.7482051282051282
#   Precision (micro): 0.7482051282051282
#   Recall (micro): 0.7482051282051282
#   F1 Score (micro): 0.7482051282051282
#
# SENTIMENTS (Multi-Label, 8 classes):
#   Precision (micro): 0.6939724557324272
#   Recall (micro): 0.5885029576823904
#   F1 Score (micro): 0.6369008535784636

# %% [markdown]
# ## Load the saved model and tokenizer

# %%
# Save model weights
torch.save(model.state_dict(), "hierarchical_multitask_model.pt")

# Save tokenizer
tokenizer.save_pretrained("saved_tokenizer/")
# Out:
# ('saved_tokenizer/tokenizer_config.json',
#  'saved_tokenizer/special_tokens_map.json',
#  'saved_tokenizer/sentencepiece.bpe.model',
#  'saved_tokenizer/added_tokens.json',
#  'saved_tokenizer/tokenizer.json')

# %%
# !mkdir -p "/content/drive/MyDrive/DS266/Project/Modeling/my_model"
# !cp hierarchical_multitask_model.pt "/content/drive/MyDrive/DS266/Project/Modeling/my_model/"
# !cp -r saved_tokenizer "/content/drive/MyDrive/DS266/Project/Modeling/my_model/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
